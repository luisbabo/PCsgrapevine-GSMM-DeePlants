# %%
from denovo_pathway_images import predict_pathways, generate_reaction_images
# Out:
# 2026-06-09 14:42:01.085444: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-09 14:42:01.137468: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-06-09 14:42:01.137537: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-06-09 14:42:01.138980: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
dataset_path = "/home/lbabo/PlantsSM/datasetpcs.csv"
output_csv = "/home/lbabo/PlantsSM/vitis_vinifera/denovo_pathway_images/resultados_finais.csv"

resultados = predict_pathways(dataset_path=dataset_path, output_csv_path=output_csv, device="cpu")
# Out:
# Retroformer model already in cache.
# [1/14] A processar: caftaric acid
# [14:45:00] DEPRECATION WARNING: please use MorganGenerator
# [14:45:02] DEPRECATION WARNING: please use MorganGenerator
# [14:45:02] DEPRECATION WARNING: please use MorganGenerator
# [14:45:02] DEPRECATION WARNING: please use MorganGenerator
# [14:45:02] DEPRECATION WARNING: please use MorganGenerator
# [14:45:02] DEPRECATION WARNING: please use MorganGenerator
# [14:45:02] DEPRECATION WARNING: please use MorganGenerator
# [14:45:02] DEPRECATION WARNING: please use MorganGenerator
# [14:45:02] DEPRECATION WARNING: please use MorganGenerator
# [14:45:02] DEPRECATION WARNING: please use MorganGenerator
# [14:45:02] DEPRECATION WARNING: please use MorganGenerator
# [14:45:02] DEPRECATION WARNING: please use MorganGenerator
# [2/14] A processar: procyanidin B2
# ...

# %%
generate_reaction_images(resultados, output_dir="/home/lbabo/PlantsSM/vitis_vinifera/denovo_pathway_images/pathway_reaction_images")
# Out:
# Desenho concluído. 14 imagens geradas na pasta '/home/lbabo/PlantsSM/vitis_vinifera/denovo_pathway_images/pathway_reaction_images'.
